# %%
import os
import pandas as pd
cwd = os.getcwd()
cwd
# Out:
# '/notebooks/ENALBO/Energy'

# %%
os.listdir(".")
# Out:
# ['.ipynb_checkpoints', 'energy_analysis.ipynb', 'REPORTE MARZO 2017.xls']

# %%
import xlrd
wb = xlrd.open_workbook(os.listdir('.')[2])
print(wb.sheet_names())
print(wb.nsheets)
# Out:
# ['DIA', 'LECTURAS', 'ARMANDIERS', 'AQUINO', 'RICHARD', 'MARCO', 'ALCON', 'BARRETO', 'Back up de lecturas', 'Hoja1']
# 10

# %%
path_to_excel = os.listdir('.')[2]
print(path_to_excel)

lecturas= pd.read_excel(path_to_excel, sheetname=1)
lecturas.head(n=20)
# Out:
# REPORTE MARZO 2017.xls
#                                   CBN - PLANTA ENALBO Unnamed: 1  Unnamed: 2  \
# 0                                                 NaN        NaN         NaN
# 1   \\avaroa\VPO-GI\PILAR-CALIDAD\A5. HIGIENE\Regi...        NaN         NaN
# 2    C O N S U M O     D E     E N E R G I A     E...        NaN         NaN
# 3                                                 NaN        NaN         NaN
# 4                                               FECHA     TURNOS  Diferencia
# 5                                                 NaN       1200         NaN
# 6                                 2014-11-30 00:00:00     MAÑANA        6.69
# 7                                                 NaN      TARDE         NaN
# 8                                                 NaN      NOCHE         NaN
# 9                                 2014-12-01 00:00:00     MAÑANA        6.75
# 10                                                NaN      TARDE         NaN
# ...

# %%
lecturas.head(n=20)
# Out:
#                                   CBN - PLANTA ENALBO Unnamed: 1  Unnamed: 2  \
# 0                                                 NaN        NaN         NaN
# 1   \\avaroa\VPO-GI\PILAR-CALIDAD\A5. HIGIENE\Regi...        NaN         NaN
# 2    C O N S U M O     D E     E N E R G I A     E...        NaN         NaN
# 3                                                 NaN        NaN         NaN
# 4                                               FECHA     TURNOS  Diferencia
# 5                                                 NaN       1200         NaN
# 6                                 2014-11-30 00:00:00     MAÑANA        6.69
# 7                                                 NaN      TARDE         NaN
# 8                                                 NaN      NOCHE         NaN
# 9                                 2014-12-01 00:00:00     MAÑANA        6.75
# 10                                                NaN      TARDE         NaN
# ...

# %%
lecturas.shape
# Out:
# (65535, 256)

# %%
lecturas= pd.read_excel(path_to_excel, skiprows=[0,1,2,3,4,6], parse_cols=[i for i in range(28)], sheetname=1)
lecturas.head()
# Out:
#        FECHA  TURNOS  Diferencia  Consumo KWh      KWH Unnamed: 5    KVArh  \
# 0 2014-11-30  MAÑANA        6.69       8028.0  6657.21        NaN  2417.24
# 1        NaT   TARDE         NaN          NaN  6660.48       3.27   2418.7
# 2        NaT   NOCHE         NaN          NaN   6663.9       3.42  2420.03
# 3 2014-12-01  MAÑANA        6.75       8100.0  6667.26       3.36  2421.45
# 4        NaT   TARDE         NaN          NaN  6669.67       2.41  2422.41
#
#   KWH BLOQUE Unnamed: 8 KWH BLOQUE.1     ...               FECHA  MAX.  \
# 0    1375.99       0.15      3283.13     ...       2014-11-29 00:00:00
# 1    1375.99          0      3286.39     ...       2014-11-29 00:00:00
# 2    1378.22       2.23      3287.59     ...       2014-11-29 00:00:00
# 3     1378.5       0.28      3288.16     ...       2014-11-29 00:00:00
# 4     1378.5          0      3290.12     ...       2014-11-29 00:00:00
#
#   KW  BLOQUE.1 HORA MAX..2        FECHA  MAX..1     FECHA DE LECTURA  \
# ...

# %%
print(lecturas)
# Out:
#            FECHA  TURNOS  Diferencia  Consumo KWh      KWH Unnamed: 5  \
# 0     2014-11-30  MAÑANA        6.69       8028.0  6657.21        NaN
# 1            NaT   TARDE         NaN          NaN  6660.48       3.27
# 2            NaT   NOCHE         NaN          NaN   6663.9       3.42
# 3     2014-12-01  MAÑANA        6.75       8100.0  6667.26       3.36
# 4            NaT   TARDE         NaN          NaN  6669.67       2.41
# 5            NaT   NOCHE         NaN          NaN  6670.65       0.98
# 6     2014-12-02  MAÑANA       12.33      14796.0  6674.01       3.36
# 7            NaT   TARDE         NaN          NaN  6679.66       5.65
# 8            NaT   NOCHE         NaN          NaN  6682.98       3.32
# 9     2014-12-03  MAÑANA       12.25      14700.0  6687.68        4.7
# 10           NaT   TARDE         NaN          NaN  6692.64       4.96
# 11           NaT   NOCHE         NaN          NaN  6695.23       2.59
# ...

# %%
#lecturas

# %%
lecturas = lecturas.drop(lecturas.columns[[2,5,8,10,12]], axis = 1)
lecturas.head()
# Out:
#        FECHA  TURNOS      KWH    KVArh KWH BLOQUE.1 KWH BLOQUE.2 HORA MAX.  \
# 0 2014-11-30  MAÑANA  6657.21  2417.24      3283.13      1998.09  18:30:00
# 1        NaT   TARDE  6660.48   2418.7      3286.39      1998.09  18:30:00
# 2        NaT   NOCHE  6663.90  2420.03      3287.59       1998.9  18:30:00
# 3 2014-12-01  MAÑANA  6667.26  2421.45      3288.16      2000.59  18:30:00
# 4        NaT   TARDE  6669.67  2422.41      3290.12      2001.04  18:30:00
#
#   KW  BLOQUE           FECHA  MAX. KW  BLOQUE.1 HORA MAX..2  \
# 0       0.636  2014-11-29 00:00:00        0.632    04:45:00
# 1       0.636  2014-11-29 00:00:00        0.632    04:45:00
# 2       0.636  2014-11-29 00:00:00        0.632    04:45:00
# 3       0.636  2014-11-29 00:00:00        0.632    04:45:00
# 4       0.636  2014-11-29 00:00:00        0.632    04:45:00
#
#          FECHA  MAX..1     FECHA DE LECTURA      HORA DE LECTURA   ADM KWH  \
# ...

# %%
column_nms = [lecturas.columns]
column_nms
# Out:
# [Index(['FECHA', 'TURNOS', 'KWH', 'KVArh', 'KWH BLOQUE.1', 'KWH BLOQUE.2',
#         'HORA MAX.', 'KW  BLOQUE ', 'FECHA  MAX.', 'KW  BLOQUE.1',
#         'HORA MAX..2', 'FECHA  MAX..1', 'FECHA DE LECTURA', 'HORA DE LECTURA',
#         'ADM KWH', 'SERV KWH', 'FRON END KWH', 'BAKE END KWH'],
#        dtype='object')]

# %%
lecturas['KWH'] = lecturas['KWH'].fillna(0.0)

# %%
for index, value in enumerate(lecturas['KWH']):
    if type(value) == type('asdf'):
        lecturas['KWH'][index] = 0.0

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.hist(lecturas['KWH'])
plt.show()

# %%
lecturas['KWH'].describe()
# Out:
# count    65529.000000
# mean       407.889991
# std       2299.394812
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      97897.900000
# Name: KWH, dtype: float64

# %%
KWH = lecturas['KWH']
print(KWH.mean())
print(KWH.median())
print(KWH.max())
print(KWH.min())
print(KWH.std())



norm_kwh = (lecturas['KWH']-np.mean(lecturas['KWH']))/np.std(lecturas['KWH'])

plt.hist(norm_kwh, 20)
plt.show()
# Out:
# 407.889990615
# 0.0
# 97897.9
# 0.0
# 2299.39481152

# %%
import numpy as np
def reject_outliers(data):
    u = np.median(data)
    s = np.std(data)
    #filtered = [e for e in data if (u - 2 * s < e < u + 2 * s)]
    #filtered = [e for e in data if e != np.max(data)]
    return filtered

filtered = reject_outliers(lecturas['KWH'])

plt.hist(filtered, 50)
plt.show()
